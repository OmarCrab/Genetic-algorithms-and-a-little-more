# %%
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
import matplotlib.pyplot as plt

# %%
breast_cancer = load_breast_cancer()
X = breast_cancer.data
Y = breast_cancer.target

clf1 = LogisticRegression()
clf1.fit(X,Y)
# Out:
# C:\object_detection\TFODCourse\Omar\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
for f, w in zip(breast_cancer.feature_names, clf1.coef_[0]):
    print("{0:<23}: {1:6.2f}".format(f,w))
# Out:
# mean radius            :   2.00
# mean texture           :   0.09
# mean perimeter         :  -0.09
# mean area              :  -0.00
# mean smoothness        :  -0.08
# mean compactness       :  -0.37
# mean concavity         :  -0.52
# mean concave points    :  -0.22
# mean symmetry          :  -0.12
# mean fractal dimension :  -0.02
# radius error           :   0.08
# texture error          :   1.00
# perimeter error        :   0.42
# area error             :  -0.15
# smoothness error       :  -0.01
# compactness error      :  -0.07
# concavity error        :  -0.11
# concave points error   :  -0.03
# symmetry error         :  -0.03
# fractal dimension error:  -0.01
# worst radius           :   2.09
# worst texture          :  -0.32
# worst perimeter        :  -0.20
# worst area             :  -0.03
# worst smoothness       :  -0.15
# worst compactness      :  -1.14
# worst concavity        :  -1.42
# worst concave points   :  -0.43
# worst symmetry         :  -0.36
# ...

# %%
clf2 = DecisionTreeClassifier(max_depth=2)
clf2.fit(X,Y)

plt.figure(figsize=(12, 8))
_ = tree.plot_tree(clf2, feature_names=breast_cancer.feature_names, class_names=breast_cancer.target_names, filled=True)
plt.show()

# %%
text_presentation = tree.export_text(clf2)
print(text_presentation)
# Out:
# |--- feature_20 <= 16.80
# |   |--- feature_27 <= 0.14
# |   |   |--- class: 1
# |   |--- feature_27 >  0.14
# |   |   |--- class: 0
# |--- feature_20 >  16.80
# |   |--- feature_21 <= 19.91
# |   |   |--- class: 1
# |   |--- feature_21 >  19.91
# |   |   |--- class: 0
